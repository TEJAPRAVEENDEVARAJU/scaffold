# %% [markdown]
# # AutoApply — Multi-Agent Job Application Assistant\nDemo notebook for the Agents Intensive Capstone Project.

# %% [markdown]
# Problem: Job hunting is repetitive. AutoApply automates discovery, tailoring, and tracking.

# %%
def mock_search(query, n=5):\n    return [{"title": f"{query} - Role {i+1}", "company": f"Company {i+1}", "apply_link":f"https://example.com/apply/{i+1}", "description": f"{query} with React"} for i in range(n)]\n\ndef basic_personalize(job, profile):\n    return f"{profile['name']} - tailored CV bullet for {job['title']}", f"Cover letter for {job['title']} at {job['company']}"\n\nprofile = {"name":"Teja Praveen","skills":["React","JavaScript","HTML"]}\njobs = mock_search("Frontend Developer", 3)\nfor j in jobs:\n    cv, cover = basic_personalize(j, profile)\n    print("Job:", j['title'])\n    print("CV:", cv)\n    print("Cover letter:", cover)\n    print("------")
